# %% [markdown]
# <a href="https://colab.research.google.com/github/RoshnaGeorge/ML/blob/main/Lab02_A6_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A6: Cosine Similarity Measure

# %%
import pandas as pd
import numpy as np

# Load the thyroid dataset
thyroid_data = pd.read_excel(
    "Lab Session Data.xlsx",
    sheet_name="thyroid0387_UCI"
)

# Display the first two observations
print(thyroid_data.head(2))
# Out:
#    Record ID  age sex on thyroxine query on thyroxine  \
# 0  840801013   29   F            f                  f
# 1  840801014   29   F            f                  f
#
#   on antithyroid medication sick pregnant thyroid surgery I131 treatment  ...  \
# 0                         f    f        f               f              f  ...
# 1                         f    f        f               f              f  ...
#
#   TT4 measured  TT4 T4U measured T4U FTI measured FTI TBG measured TBG  \
# 0            f    ?            f   ?            f   ?            f   ?
# 1            t  128            f   ?            f   ?            f   ?
#
#   referral source     Condition
# 0           other  NO CONDITION
# 1           other  NO CONDITION
#
# [2 rows x 31 columns]

# %% [markdown]
# complete vectors

# %%
# Select the first two complete observations
first_two_observations = thyroid_data.iloc[:2].copy()

# Replace '?' with missing values
first_two_observations = first_two_observations.replace('?', np.nan)

# Convert categorical attributes into numerical form using One-Hot Encoding
encoded_data = pd.get_dummies(first_two_observations, dummy_na=True)

# Convert all values to numeric type
encoded_data = encoded_data.astype(float)

# Replace any remaining missing values with 0
encoded_data = encoded_data.fillna(0)

# Extract the two complete numerical vectors
vector_A = encoded_data.iloc[0].to_numpy()
vector_B = encoded_data.iloc[1].to_numpy()

print("Vector A:")
print(vector_A)

print("\nVector B:")
print(vector_B)

print("\nLength of Vector A:", len(vector_A))
print("Length of Vector B:", len(vector_B))
# Out:
# Vector A:
# [8.40801013e+08 2.90000000e+01 3.00000000e-01 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00
#  1.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00
#  1.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00
#  1.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 1.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 1.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 1.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 1.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.00000000e+00 0.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 1.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00 1.00000000e+00 0.00000000e+00 1.00000000e+00
#  0.00000000e+00]
#
# Vector B:
# [8.40801014e+08 2.90000000e+01 1.60000000e+00 1.90000000e+00
# ...

# %% [markdown]
# cosine similarity

# %%
# Calculate the dot product of A and B
dot_product = np.dot(vector_A, vector_B)

# Calculate the magnitude of Vector A
magnitude_A = np.linalg.norm(vector_A)

# Calculate the magnitude of Vector B
magnitude_B = np.linalg.norm(vector_B)

# Calculate Cosine Similarity
cosine_similarity = dot_product / (magnitude_A * magnitude_B)

# Display the results
print("Dot Product of A and B:", dot_product)
print("Magnitude of Vector A:", magnitude_A)
print("Magnitude of Vector B:", magnitude_B)
print("Cosine Similarity:", cosine_similarity)
# Out:
# Dot Product of A and B: 7.069463443026281e+17
# Magnitude of Vector A: 840801013.0000006
# Magnitude of Vector B: 840801014.0000103
# Cosine Similarity: 0.9999999999999885
